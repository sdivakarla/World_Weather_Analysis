# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
import json

# %%
import requests
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Import the API key.
from config import weather_api_key
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 717

# %%
# Use the tuple() function to display the latitude and longitude combinations.
# for coordinate in coordinates:
#     print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
#           citipy.nearest_city(coordinate[0], coordinate[1]).country_code)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):


    # Group cities in sets of 50 for logging purposes.
        if (i % 50 == 0 and i >= 50):
            set_count += 1
            record_count = 1
            time.sleep(60)

    # Create endpoint URL with each city.
        city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
        print(f"Processing Record {record_count} of Set {set_count} | {city}")
        # Add 1 to the record count.
        record_count += 1
        
        # Run an API request for each of the cities.
        try:
        # Parse the JSON and retrieve data.
            city_weather = requests.get(city_url).json()
        # Parse out the needed data.
            city_lat = city_weather["coord"]["lat"]
            city_lng = city_weather["coord"]["lon"]
            city_max_temp = city_weather["main"]["temp_max"]
            city_humidity = city_weather["main"]["humidity"]
            city_clouds = city_weather["clouds"]["all"]
            city_wind = city_weather["wind"]["speed"]
            city_country = city_weather["sys"]["country"]
            weather_description = city_weather["weather"][0]['description']
        # Convert the date to ISO standard.
            city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
            city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": weather_description,
                          "Date": city_date})

        # If an error is experienced, skip the city.
        except:
            print("City not found. Skipping...")
            pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ponnani
# Processing Record 2 of Set 1 | sladkovo
# Processing Record 3 of Set 1 | saint-philippe
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 1 | karachi
# Processing Record 7 of Set 1 | butaritari
# Processing Record 8 of Set 1 | hilo
# Processing Record 9 of Set 1 | muros
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | atuona
# Processing Record 12 of Set 1 | taburi
# City not found. Skipping...
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | port elizabeth
# Processing Record 15 of Set 1 | at-bashi
# Processing Record 16 of Set 1 | bredasdorp
# Processing Record 17 of Set 1 | busselton
# Processing Record 18 of Set 1 | east london
# Processing Record 19 of Set 1 | new norfolk
# Processing Record 20 of Set 1 | souillac
# Processing Record 21 of Set 1 | tabou
# Processing Record 22 of Set 1 | cape town
# Processing Record 23 of Set 1 | diego de almagro
# Processing Record 24 of Set 1 | hobart
# Processing Record 25 of Set 1 | faanui
# Processing Record 26 of Set 1 | acapulco
# Processing Record 27 of Set 1 | omboue
# Processing Record 28 of Set 1 | ushuaia
# Processing Record 29 of Set 1 | pouembout
# Processing Record 30 of Set 1 | dikson
# Processing Record 31 of Set 1 | hermanus
# Processing Record 32 of Set 1 | qaanaaq
# Processing Record 33 of Set 1 | maibong
# Processing Record 34 of Set 1 | thompson
# Processing Record 35 of Set 1 | sibolga
# Processing Record 36 of Set 1 | victor harbor
# Processing Record 37 of Set 1 | esperance
# Processing Record 38 of Set 1 | zhigalovo
# Processing Record 39 of Set 1 | hithadhoo
# Processing Record 40 of Set 1 | vaini
# Processing Record 41 of Set 1 | lebu
# Processing Record 42 of Set 1 | floro
# Processing Record 43 of Set 1 | carnarvon
# Processing Record 44 of Set 1 | la rioja
# Processing Record 45 of Set 1 | atar
# Processing Record 46 of Set 1 | lompoc
# Processing Record 47 of Set 1 | naze
# Processing Record 48 of Set 1 | yantarnyy
# Processing Record 49 of Set 1 | abu samrah
# Processing Record 50 of Set 1 | alofi
# Processing Record 1 of Set 2 | torbay
# Processing Record 2 of Set 2 | khatanga
# Processing Record 3 of Set 2 | bluff
# Processing Record 4 of Set 2 | haapiti
# Processing Record 5 of Set 2 | kidal
# Processing Record 6 of Set 2 | kruisfontein
# Processing Record 7 of Set 2 | pimentel
# Processing Record 8 of Set 2 | severo-kurilsk
# Processing Record 9 of Set 2 | arraial do cabo
# Processing Record 10 of Set 2 | punta arenas
# Processing Record 11 of Set 2 | foam lake
# Processing Record 12 of Set 2 | nacala
# Processing Record 13 of Set 2 | kapaa
# Processing Record 14 of Set 2 | butembo
# Processing Record 15 of Set 2 | kavieng
# Processing Record 16 of Set 2 | mar del plata
# Processing Record 17 of Set 2 | polignano a mare
# Processing Record 18 of Set 2 | kaitangata
# Processing Record 19 of Set 2 | pyaozerskiy
# Processing Record 20 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 2 | chuy
# Processing Record 22 of Set 2 | te anau
# Processing Record 23 of Set 2 | hastings
# Processing Record 24 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 2 | ponta do sol
# Processing Record 26 of Set 2 | chokurdakh
# Processing Record 27 of Set 2 | nanzhang
# Processing Record 28 of Set 2 | along
# Processing Record 29 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 2 | tawau
# Processing Record 31 of Set 2 | puerto ayora
# Processing Record 32 of Set 2 | agadez
# Processing Record 33 of Set 2 | jamestown
# Processing Record 34 of Set 2 | betioky
# Processing Record 35 of Set 2 | komsomolskiy
# Processing Record 36 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 2 | rocha
# Processing Record 38 of Set 2 | cherskiy
# Processing Record 39 of Set 2 | sao joao da barra
# Processing Record 40 of Set 2 | port alfred
# Processing Record 41 of Set 2 | chernyakhovsk
# Processing Record 42 of Set 2 | skalnyy
# City not found. Skipping...
# Processing Record 43 of Set 2 | nemuro
# Processing Record 44 of Set 2 | pochutla
# Processing Record 45 of Set 2 | tomatlan
# Processing Record 46 of Set 2 | cordoba
# Processing Record 47 of Set 2 | bambous virieux
# Processing Record 48 of Set 2 | kodiak
# Processing Record 49 of Set 2 | castro
# Processing Record 50 of Set 2 | marawi
# Processing Record 1 of Set 3 | isangel
# Processing Record 2 of Set 3 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 3 of Set 3 | caceres
# Processing Record 4 of Set 3 | vardo
# Processing Record 5 of Set 3 | marsa matruh
# Processing Record 6 of Set 3 | haines junction
# Processing Record 7 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 3 | nuuk
# Processing Record 9 of Set 3 | pacific grove
# Processing Record 10 of Set 3 | belle fourche
# Processing Record 11 of Set 3 | longyearbyen
# Processing Record 12 of Set 3 | shevchenkove
# Processing Record 13 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 3 | heiligenhafen
# Processing Record 15 of Set 3 | moreira sales
# Processing Record 16 of Set 3 | provideniya
# Processing Record 17 of Set 3 | arawa
# Processing Record 18 of Set 3 | tuktoyaktuk
# Processing Record 19 of Set 3 | zakupne
# Processing Record 20 of Set 3 | mana
# Processing Record 21 of Set 3 | laguna
# Processing Record 22 of Set 3 | aykhal
# Processing Record 23 of Set 3 | sisimiut
# Processing Record 24 of Set 3 | cap malheureux
# Processing Record 25 of Set 3 | ostrovnoy
# Processing Record 26 of Set 3 | bundaberg
# Processing Record 27 of Set 3 | barrow
# Processing Record 28 of Set 3 | pandan
# Processing Record 29 of Set 3 | saint george
# Processing Record 30 of Set 3 | eura
# Processing Record 31 of Set 3 | vila velha
# Processing Record 32 of Set 3 | gerash
# Processing Record 33 of Set 3 | bata
# Processing Record 34 of Set 3 | pyay
# Processing Record 35 of Set 3 | port hardy
# Processing Record 36 of Set 3 | tuatapere
# Processing Record 37 of Set 3 | chulym
# Processing Record 38 of Set 3 | chenghai
# Processing Record 39 of Set 3 | airai
# Processing Record 40 of Set 3 | tasiilaq
# Processing Record 41 of Set 3 | fortuna
# Processing Record 42 of Set 3 | richards bay
# Processing Record 43 of Set 3 | christchurch
# Processing Record 44 of Set 3 | ribeira grande
# Processing Record 45 of Set 3 | palmer
# Processing Record 46 of Set 3 | santa ines
# Processing Record 47 of Set 3 | esna
# Processing Record 48 of Set 3 | waipawa
# Processing Record 49 of Set 3 | fano
# Processing Record 50 of Set 3 | srednekolymsk
# Processing Record 1 of Set 4 | lakes entrance
# Processing Record 2 of Set 4 | susanville
# Processing Record 3 of Set 4 | manaure
# Processing Record 4 of Set 4 | brae
# Processing Record 5 of Set 4 | adrar
# Processing Record 6 of Set 4 | san quintin
# Processing Record 7 of Set 4 | cairns
# Processing Record 8 of Set 4 | porto novo
# Processing Record 9 of Set 4 | swan river
# Processing Record 10 of Set 4 | deputatskiy
# Processing Record 11 of Set 4 | kobojango
# City not found. Skipping...
# Processing Record 12 of Set 4 | ancud
# Processing Record 13 of Set 4 | nipawin
# Processing Record 14 of Set 4 | eydhafushi
# Processing Record 15 of Set 4 | nikolskoye
# Processing Record 16 of Set 4 | bengkulu
# Processing Record 17 of Set 4 | ternate
# Processing Record 18 of Set 4 | pychas
# Processing Record 19 of Set 4 | oum hadjer
# Processing Record 20 of Set 4 | bangui
# Processing Record 21 of Set 4 | zhanakorgan
# Processing Record 22 of Set 4 | richard toll
# City not found. Skipping...
# Processing Record 23 of Set 4 | novaya igirma
# Processing Record 24 of Set 4 | salinopolis
# Processing Record 25 of Set 4 | upernavik
# Processing Record 26 of Set 4 | nabire
# Processing Record 27 of Set 4 | jiddah
# City not found. Skipping...
# Processing Record 28 of Set 4 | domoni
# Processing Record 29 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 30 of Set 4 | coihaique
# Processing Record 31 of Set 4 | constitucion
# Processing Record 32 of Set 4 | payson
# Processing Record 33 of Set 4 | ambon
# Processing Record 34 of Set 4 | nouadhibou
# Processing Record 35 of Set 4 | mahebourg
# Processing Record 36 of Set 4 | palana
# Processing Record 37 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 4 | lardos
# Processing Record 39 of Set 4 | atmakur
# Processing Record 40 of Set 4 | qaqortoq
# Processing Record 41 of Set 4 | sambava
# Processing Record 42 of Set 4 | avera
# Processing Record 43 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 4 | cururupu
# Processing Record 45 of Set 4 | nanakuli
# Processing Record 46 of Set 4 | saldanha
# Processing Record 47 of Set 4 | barranca
# Processing Record 48 of Set 4 | karkaralinsk
# City not found. Skipping...
# Processing Record 49 of Set 4 | flinders
# Processing Record 50 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 1 of Set 5 | antofagasta
# Processing Record 2 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 3 of Set 5 | juneau
# Processing Record 4 of Set 5 | portland
# Processing Record 5 of Set 5 | sorland
# Processing Record 6 of Set 5 | tocopilla
# Processing Record 7 of Set 5 | geraldton
# Processing Record 8 of Set 5 | havoysund
# Processing Record 9 of Set 5 | umm bab
# Processing Record 10 of Set 5 | mayo
# Processing Record 11 of Set 5 | ilula
# Processing Record 12 of Set 5 | litoral del san juan
# City not found. Skipping...
# Processing Record 13 of Set 5 | yar-sale
# Processing Record 14 of Set 5 | tambopata
# Processing Record 15 of Set 5 | tiksi
# Processing Record 16 of Set 5 | beringovskiy
# Processing Record 17 of Set 5 | shenjiamen
# Processing Record 18 of Set 5 | gat
# Processing Record 19 of Set 5 | georgetown
# Processing Record 20 of Set 5 | rogers
# Processing Record 21 of Set 5 | mildura
# Processing Record 22 of Set 5 | kamenka
# Processing Record 23 of Set 5 | westport
# Processing Record 24 of Set 5 | brookhaven
# Processing Record 25 of Set 5 | san carlos de bariloche
# Processing Record 26 of Set 5 | corn island
# Processing Record 27 of Set 5 | bucak
# Processing Record 28 of Set 5 | sao filipe
# Processing Record 29 of Set 5 | dzhusaly
# City not found. Skipping...
# Processing Record 30 of Set 5 | norman wells
# Processing Record 31 of Set 5 | san vicente
# Processing Record 32 of Set 5 | chapais
# Processing Record 33 of Set 5 | sinnamary
# Processing Record 34 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 35 of Set 5 | yellowknife
# Processing Record 36 of Set 5 | kasongo-lunda
# Processing Record 37 of Set 5 | pundaguitan
# Processing Record 38 of Set 5 | labuhan
# Processing Record 39 of Set 5 | curumani
# Processing Record 40 of Set 5 | ballina
# Processing Record 41 of Set 5 | tanshui
# City not found. Skipping...
# Processing Record 42 of Set 5 | boysun
# Processing Record 43 of Set 5 | san alberto
# Processing Record 44 of Set 5 | zhigansk
# Processing Record 45 of Set 5 | half moon bay
# Processing Record 46 of Set 5 | itarema
# Processing Record 47 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 48 of Set 5 | antalaha
# Processing Record 49 of Set 5 | kuytun
# Processing Record 50 of Set 5 | savelugu
# Processing Record 1 of Set 6 | ilulissat
# Processing Record 2 of Set 6 | denpasar
# Processing Record 3 of Set 6 | kiama
# Processing Record 4 of Set 6 | beloha
# Processing Record 5 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 6 | menongue
# Processing Record 7 of Set 6 | bagotville
# Processing Record 8 of Set 6 | avarua
# Processing Record 9 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 10 of Set 6 | tiznit
# Processing Record 11 of Set 6 | okakarara
# Processing Record 12 of Set 6 | korla
# Processing Record 13 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 14 of Set 6 | bilibino
# Processing Record 15 of Set 6 | almaznyy
# Processing Record 16 of Set 6 | lavrentiya
# Processing Record 17 of Set 6 | iranshahr
# Processing Record 18 of Set 6 | kirakira
# Processing Record 19 of Set 6 | narsaq
# Processing Record 20 of Set 6 | musafirkhana
# Processing Record 21 of Set 6 | sitka
# Processing Record 22 of Set 6 | salina
# Processing Record 23 of Set 6 | carutapera
# Processing Record 24 of Set 6 | manadhoo
# Processing Record 25 of Set 6 | salinas
# Processing Record 26 of Set 6 | maridi
# Processing Record 27 of Set 6 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 28 of Set 6 | yarmouth
# Processing Record 29 of Set 6 | darhan
# Processing Record 30 of Set 6 | demba
# Processing Record 31 of Set 6 | esmeraldas
# Processing Record 32 of Set 6 | calvinia
# Processing Record 33 of Set 6 | santa maria
# Processing Record 34 of Set 6 | popondetta
# Processing Record 35 of Set 6 | talnakh
# Processing Record 36 of Set 6 | yucca valley
# Processing Record 37 of Set 6 | ankazoabo
# Processing Record 38 of Set 6 | okha
# Processing Record 39 of Set 6 | ayan
# Processing Record 40 of Set 6 | vao
# Processing Record 41 of Set 6 | matadi
# Processing Record 42 of Set 6 | andenes
# Processing Record 43 of Set 6 | puerto escondido
# Processing Record 44 of Set 6 | victoria
# Processing Record 45 of Set 6 | mogadishu
# Processing Record 46 of Set 6 | miramar
# Processing Record 47 of Set 6 | bethel
# Processing Record 48 of Set 6 | lorengau
# Processing Record 49 of Set 6 | bowen
# Processing Record 50 of Set 6 | hamilton
# Processing Record 1 of Set 7 | saskylakh
# Processing Record 2 of Set 7 | lagoa
# Processing Record 3 of Set 7 | nakajo
# City not found. Skipping...
# Processing Record 4 of Set 7 | inderborskiy
# City not found. Skipping...
# Processing Record 5 of Set 7 | auki
# Processing Record 6 of Set 7 | ada
# Processing Record 7 of Set 7 | plymouth
# Processing Record 8 of Set 7 | leningradskiy
# Processing Record 9 of Set 7 | beberibe
# Processing Record 10 of Set 7 | general cepeda
# Processing Record 11 of Set 7 | mao
# Processing Record 12 of Set 7 | zaozerne
# Processing Record 13 of Set 7 | kargasok
# Processing Record 14 of Set 7 | pisco
# Processing Record 15 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 16 of Set 7 | santiago
# Processing Record 17 of Set 7 | selma
# Processing Record 18 of Set 7 | san patricio
# Processing Record 19 of Set 7 | olinda
# Processing Record 20 of Set 7 | viedma
# Processing Record 21 of Set 7 | hit
# Processing Record 22 of Set 7 | spearfish
# Processing Record 23 of Set 7 | yirol
# City not found. Skipping...
# Processing Record 24 of Set 7 | tautira
# Processing Record 25 of Set 7 | ewa beach
# Processing Record 26 of Set 7 | svetlogorsk
# Processing Record 27 of Set 7 | tateyama
# Processing Record 28 of Set 7 | cabo san lucas
# Processing Record 29 of Set 7 | wuwei
# Processing Record 30 of Set 7 | liberia
# Processing Record 31 of Set 7 | grindavik
# Processing Record 32 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 7 | davila
# Processing Record 34 of Set 7 | mushie
# Processing Record 35 of Set 7 | aswan
# Processing Record 36 of Set 7 | cayenne
# Processing Record 37 of Set 7 | redlands
# Processing Record 38 of Set 7 | waingapu
# Processing Record 39 of Set 7 | nome
# Processing Record 40 of Set 7 | los andes
# Processing Record 41 of Set 7 | kollumerland
# City not found. Skipping...
# Processing Record 42 of Set 7 | meulaboh
# Processing Record 43 of Set 7 | krasnoselkup
# Processing Record 44 of Set 7 | pousat
# City not found. Skipping...
# Processing Record 45 of Set 7 | marzuq
# Processing Record 46 of Set 7 | husavik
# Processing Record 47 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 48 of Set 7 | zhanaozen
# Processing Record 49 of Set 7 | pevek
# Processing Record 50 of Set 7 | mugur-aksy
# Processing Record 1 of Set 8 | buala
# Processing Record 2 of Set 8 | tongren
# Processing Record 3 of Set 8 | zarand
# Processing Record 4 of Set 8 | yenagoa
# Processing Record 5 of Set 8 | dingle
# Processing Record 6 of Set 8 | harrisburg
# Processing Record 7 of Set 8 | ati
# Processing Record 8 of Set 8 | teya
# Processing Record 9 of Set 8 | berlevag
# Processing Record 10 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 11 of Set 8 | nanortalik
# Processing Record 12 of Set 8 | parabel
# Processing Record 13 of Set 8 | los llanos de aridane
# Processing Record 14 of Set 8 | nouakchott
# Processing Record 15 of Set 8 | novovasylivka
# Processing Record 16 of Set 8 | port lincoln
# Processing Record 17 of Set 8 | aksha
# Processing Record 18 of Set 8 | la ronge
# Processing Record 19 of Set 8 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 20 of Set 8 | bubaque
# Processing Record 21 of Set 8 | lilongwe
# Processing Record 22 of Set 8 | seoul
# Processing Record 23 of Set 8 | singapore
# Processing Record 24 of Set 8 | panzhihua
# Processing Record 25 of Set 8 | tselinnoye
# Processing Record 26 of Set 8 | arlit
# Processing Record 27 of Set 8 | bontang
# Processing Record 28 of Set 8 | san angelo
# Processing Record 29 of Set 8 | guerrero negro
# Processing Record 30 of Set 8 | kysyl-syr
# Processing Record 31 of Set 8 | fare
# Processing Record 32 of Set 8 | yankton
# Processing Record 33 of Set 8 | plouzane
# Processing Record 34 of Set 8 | aksu
# Processing Record 35 of Set 8 | pacifica
# Processing Record 36 of Set 8 | cumaribo
# City not found. Skipping...
# Processing Record 37 of Set 8 | diamantino
# Processing Record 38 of Set 8 | ondjiva
# Processing Record 39 of Set 8 | tura
# Processing Record 40 of Set 8 | raga
# Processing Record 41 of Set 8 | sylvania
# Processing Record 42 of Set 8 | termoli
# Processing Record 43 of Set 8 | poya
# Processing Record 44 of Set 8 | fayaoue
# Processing Record 45 of Set 8 | college
# Processing Record 46 of Set 8 | alice springs
# Processing Record 47 of Set 8 | touros
# Processing Record 48 of Set 8 | dauphin
# Processing Record 49 of Set 8 | matagami
# Processing Record 50 of Set 8 | smolenka
# Processing Record 1 of Set 9 | omsukchan
# Processing Record 2 of Set 9 | katsuura
# Processing Record 3 of Set 9 | clyde river
# Processing Record 4 of Set 9 | bairiki
# Processing Record 5 of Set 9 | bacolod
# Processing Record 6 of Set 9 | codrington
# Processing Record 7 of Set 9 | pareora
# Processing Record 8 of Set 9 | saint-pierre
# Processing Record 9 of Set 9 | akdepe
# Processing Record 10 of Set 9 | tawkar
# City not found. Skipping...
# Processing Record 11 of Set 9 | karauzyak
# City not found. Skipping...
# Processing Record 12 of Set 9 | wanning
# Processing Record 13 of Set 9 | kavaratti
# Processing Record 14 of Set 9 | venado tuerto
# Processing Record 15 of Set 9 | fort nelson
# Processing Record 16 of Set 9 | kichmengskiy gorodok
# Processing Record 17 of Set 9 | porto velho
# Processing Record 18 of Set 9 | klaksvik
# Processing Record 19 of Set 9 | berzasca
# Processing Record 20 of Set 9 | tevaitoa
# Processing Record 21 of Set 9 | tilichiki
# Processing Record 22 of Set 9 | kontagora
# Processing Record 23 of Set 9 | carson city
# Processing Record 24 of Set 9 | helsinki
# Processing Record 25 of Set 9 | cockburn town
# Processing Record 26 of Set 9 | griffith
# Processing Record 27 of Set 9 | arona
# Processing Record 28 of Set 9 | plettenberg bay
# Processing Record 29 of Set 9 | ketchikan
# Processing Record 30 of Set 9 | broome
# Processing Record 31 of Set 9 | kanash
# Processing Record 32 of Set 9 | trinidad
# Processing Record 33 of Set 9 | dongying
# Processing Record 34 of Set 9 | buchanan
# Processing Record 35 of Set 9 | bereda
# Processing Record 36 of Set 9 | burica
# City not found. Skipping...
# Processing Record 37 of Set 9 | henties bay
# Processing Record 38 of Set 9 | kahului
# Processing Record 39 of Set 9 | konya
# Processing Record 40 of Set 9 | knysna
# Processing Record 41 of Set 9 | san borja
# Processing Record 42 of Set 9 | ixtapa
# Processing Record 43 of Set 9 | blagoyevo
# Processing Record 44 of Set 9 | luau
# Processing Record 45 of Set 9 | igarka
# Processing Record 46 of Set 9 | tahe
# Processing Record 47 of Set 9 | katangli
# Processing Record 48 of Set 9 | kachikau
# City not found. Skipping...
# Processing Record 49 of Set 9 | san rafael
# Processing Record 50 of Set 9 | mazagao
# Processing Record 1 of Set 10 | ahipara
# Processing Record 2 of Set 10 | toungoo
# City not found. Skipping...
# Processing Record 3 of Set 10 | bandarbeyla
# Processing Record 4 of Set 10 | cam pha
# City not found. Skipping...
# Processing Record 5 of Set 10 | russell
# Processing Record 6 of Set 10 | chiang khong
# Processing Record 7 of Set 10 | rawson
# Processing Record 8 of Set 10 | yamada
# Processing Record 9 of Set 10 | amahai
# Processing Record 10 of Set 10 | segamat
# Processing Record 11 of Set 10 | acari
# Processing Record 12 of Set 10 | san francisco
# Processing Record 13 of Set 10 | longlac
# City not found. Skipping...
# Processing Record 14 of Set 10 | ust-barguzin
# Processing Record 15 of Set 10 | rancho palos verdes
# Processing Record 16 of Set 10 | mount isa
# Processing Record 17 of Set 10 | balykshi
# Processing Record 18 of Set 10 | asau
# Processing Record 19 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 20 of Set 10 | south valley
# Processing Record 21 of Set 10 | porto walter
# Processing Record 22 of Set 10 | neiafu
# Processing Record 23 of Set 10 | marfino
# Processing Record 24 of Set 10 | soe
# Processing Record 25 of Set 10 | tessalit
# Processing Record 26 of Set 10 | manokwari
# Processing Record 27 of Set 10 | luderitz
# Processing Record 28 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 10 | laon
# Processing Record 30 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 10 | salalah
# Processing Record 32 of Set 10 | fevralsk
# City not found. Skipping...
# Processing Record 33 of Set 10 | ascension
# Processing Record 34 of Set 10 | miami
# Processing Record 35 of Set 10 | vanimo
# Processing Record 36 of Set 10 | salsomaggiore terme
# Processing Record 37 of Set 10 | tuni
# Processing Record 38 of Set 10 | gundlupet
# Processing Record 39 of Set 10 | albury
# Processing Record 40 of Set 10 | klyuchi
# Processing Record 41 of Set 10 | tarudant
# City not found. Skipping...
# Processing Record 42 of Set 10 | rio grande
# Processing Record 43 of Set 10 | estelle
# Processing Record 44 of Set 10 | louis trichardt
# Processing Record 45 of Set 10 | rock springs
# Processing Record 46 of Set 10 | sabha
# Processing Record 47 of Set 10 | kutahya
# Processing Record 48 of Set 10 | pointe michel
# Processing Record 49 of Set 10 | ponta delgada
# Processing Record 50 of Set 10 | port-gentil
# Processing Record 1 of Set 11 | havre-saint-pierre
# Processing Record 2 of Set 11 | surgut
# Processing Record 3 of Set 11 | mananara
# Processing Record 4 of Set 11 | biak
# Processing Record 5 of Set 11 | keti bandar
# Processing Record 6 of Set 11 | namibe
# Processing Record 7 of Set 11 | sibu
# Processing Record 8 of Set 11 | cidreira
# Processing Record 9 of Set 11 | imuris
# Processing Record 10 of Set 11 | dalby
# Processing Record 11 of Set 11 | okhotsk
# Processing Record 12 of Set 11 | tabas
# Processing Record 13 of Set 11 | samarai
# Processing Record 14 of Set 11 | jinchengjiang
# City not found. Skipping...
# Processing Record 15 of Set 11 | sur
# Processing Record 16 of Set 11 | fukue
# Processing Record 17 of Set 11 | port macquarie
# Processing Record 18 of Set 11 | channel-port aux basques
# Processing Record 19 of Set 11 | lagos
# Processing Record 20 of Set 11 | pascagoula
# Processing Record 21 of Set 11 | katherine
# Processing Record 22 of Set 11 | susangerd
# Processing Record 23 of Set 11 | taoudenni
# Processing Record 24 of Set 11 | pianco
# Processing Record 25 of Set 11 | olafsvik
# Processing Record 26 of Set 11 | mundo nuevo
# Processing Record 27 of Set 11 | maceio
# Processing Record 28 of Set 11 | luocheng
# Processing Record 29 of Set 11 | yalvac
# Processing Record 30 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 31 of Set 11 | guiratinga
# Processing Record 32 of Set 11 | xinqing
# Processing Record 33 of Set 11 | sylva
# Processing Record 34 of Set 11 | zolotinka
# City not found. Skipping...
# Processing Record 35 of Set 11 | shenzhen
# Processing Record 36 of Set 11 | esil
# Processing Record 37 of Set 11 | qostanay
# Processing Record 38 of Set 11 | altamont
# Processing Record 39 of Set 11 | cookeville
# Processing Record 40 of Set 11 | omurtag
# Processing Record 41 of Set 11 | moron
# Processing Record 42 of Set 11 | artyk
# City not found. Skipping...
# Processing Record 43 of Set 11 | barillas
# Processing Record 44 of Set 11 | puteyets
# Processing Record 45 of Set 11 | borogontsy
# Processing Record 46 of Set 11 | zaltan
# Processing Record 47 of Set 11 | dire
# Processing Record 48 of Set 11 | natal
# Processing Record 49 of Set 11 | yablonovo
# Processing Record 50 of Set 11 | san policarpo
# Processing Record 1 of Set 12 | araouane
# Processing Record 2 of Set 12 | zyryanka
# Processing Record 3 of Set 12 | amberley
# Processing Record 4 of Set 12 | teykovo
# Processing Record 5 of Set 12 | yeghegnavan
# Processing Record 6 of Set 12 | krasnyy yar
# Processing Record 7 of Set 12 | gold coast
# Processing Record 8 of Set 12 | ucluelet
# Processing Record 9 of Set 12 | ambodifototra
# City not found. Skipping...
# Processing Record 10 of Set 12 | lokoja
# Processing Record 11 of Set 12 | aktau
# Processing Record 12 of Set 12 | dubbo
# Processing Record 13 of Set 12 | ola
# Processing Record 14 of Set 12 | kokoda
# Processing Record 15 of Set 12 | gbarnga
# Processing Record 16 of Set 12 | majene
# Processing Record 17 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 18 of Set 12 | verkhnevilyuysk
# Processing Record 19 of Set 12 | mtwara
# Processing Record 20 of Set 12 | harper
# Processing Record 21 of Set 12 | shache
# Processing Record 22 of Set 12 | namatanai
# Processing Record 23 of Set 12 | hasaki
# Processing Record 24 of Set 12 | sarakhs
# Processing Record 25 of Set 12 | iqaluit
# Processing Record 26 of Set 12 | palmeirais
# Processing Record 27 of Set 12 | dubai
# Processing Record 28 of Set 12 | jiaojiang
# Processing Record 29 of Set 12 | palatka
# Processing Record 30 of Set 12 | bandar-e anzali
# Processing Record 31 of Set 12 | rio negrinho
# Processing Record 32 of Set 12 | genhe
# Processing Record 33 of Set 12 | colac
# Processing Record 34 of Set 12 | general roca
# Processing Record 35 of Set 12 | artvin
# Processing Record 36 of Set 12 | goundam
# Processing Record 37 of Set 12 | bandikui
# Processing Record 38 of Set 12 | bulgan
# Processing Record 39 of Set 12 | puerto del rosario
# Processing Record 40 of Set 12 | finschhafen
# Processing Record 41 of Set 12 | bitkine
# Processing Record 42 of Set 12 | bac lieu
# Processing Record 43 of Set 12 | saint anthony
# Processing Record 44 of Set 12 | eureka
# Processing Record 45 of Set 12 | rolim de moura
# City not found. Skipping...
# Processing Record 46 of Set 12 | hihya
# Processing Record 47 of Set 12 | cornwall
# Processing Record 48 of Set 12 | monywa
# Processing Record 49 of Set 12 | hami
# Processing Record 50 of Set 12 | castrillon
# Processing Record 1 of Set 13 | wyndham
# Processing Record 2 of Set 13 | wamba
# Processing Record 3 of Set 13 | comodoro rivadavia
# Processing Record 4 of Set 13 | puerto leguizamo
# Processing Record 5 of Set 13 | buariki
# City not found. Skipping...
# Processing Record 6 of Set 13 | tokmak
# Processing Record 7 of Set 13 | gwanda
# Processing Record 8 of Set 13 | marrakesh
# Processing Record 9 of Set 13 | padang
# Processing Record 10 of Set 13 | vytegra
# Processing Record 11 of Set 13 | male
# Processing Record 12 of Set 13 | paddhari
# Processing Record 13 of Set 13 | frederico westphalen
# Processing Record 14 of Set 13 | santa ana
# Processing Record 15 of Set 13 | san luis
# Processing Record 16 of Set 13 | hualmay
# Processing Record 17 of Set 13 | amambai
# Processing Record 18 of Set 13 | aliaga
# Processing Record 19 of Set 13 | inuvik
# Processing Record 20 of Set 13 | silifke
# Processing Record 21 of Set 13 | hofn
# Processing Record 22 of Set 13 | cheuskiny
# City not found. Skipping...
# Processing Record 23 of Set 13 | mehamn
# Processing Record 24 of Set 13 | zlatoustovsk
# City not found. Skipping...
# Processing Record 25 of Set 13 | rodrigues alves
# Processing Record 26 of Set 13 | la seyne-sur-mer
# Processing Record 27 of Set 13 | bemidji
# Processing Record 28 of Set 13 | churapcha
# Processing Record 29 of Set 13 | boa esperanca
# Processing Record 30 of Set 13 | aklavik
# Processing Record 31 of Set 13 | akhmim
# Processing Record 32 of Set 13 | kutum
# Processing Record 33 of Set 13 | shiyan
# Processing Record 34 of Set 13 | makakilo city
# Processing Record 35 of Set 13 | morant bay
# Processing Record 36 of Set 13 | matara
# Processing Record 37 of Set 13 | selu
# Processing Record 38 of Set 13 | praya
# Processing Record 39 of Set 13 | qiongshan
# Processing Record 40 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 41 of Set 13 | lumut
# Processing Record 42 of Set 13 | stykkisholmur
# Processing Record 43 of Set 13 | burnie
# Processing Record 44 of Set 13 | grand gaube
# Processing Record 45 of Set 13 | harare
# Processing Record 46 of Set 13 | ondorhaan
# City not found. Skipping...
# Processing Record 47 of Set 13 | san juan
# Processing Record 48 of Set 13 | pasni
# Processing Record 49 of Set 13 | clearlake
# Processing Record 50 of Set 13 | bolshoye bunkovo
# City not found. Skipping...
# Processing Record 1 of Set 14 | nanjing
# Processing Record 2 of Set 14 | inhambane
# Processing Record 3 of Set 14 | bulaevo
# Processing Record 4 of Set 14 | columbus
# Processing Record 5 of Set 14 | kafue
# Processing Record 6 of Set 14 | victor rosales
# Processing Record 7 of Set 14 | vung tau
# Processing Record 8 of Set 14 | zabid
# Processing Record 9 of Set 14 | awjilah
# Processing Record 10 of Set 14 | kuragino
# Processing Record 11 of Set 14 | bakel
# Processing Record 12 of Set 14 | lakhimpur
# Processing Record 13 of Set 14 | hvammstangi
# City not found. Skipping...
# Processing Record 14 of Set 14 | takoradi
# Processing Record 15 of Set 14 | shimoda
# Processing Record 16 of Set 14 | pombas
# Processing Record 17 of Set 14 | mlawa
# Processing Record 18 of Set 14 | hatillo
# Processing Record 19 of Set 14 | necochea
# Processing Record 20 of Set 14 | quatre cocos
# Processing Record 21 of Set 14 | bahir dar
# Processing Record 22 of Set 14 | ambilobe
# Processing Record 23 of Set 14 | kumluca
# Processing Record 24 of Set 14 | kuryk
# Processing Record 25 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 14 | timaru
# Processing Record 27 of Set 14 | pemangkat
# Processing Record 28 of Set 14 | poum
# Processing Record 29 of Set 14 | memaliaj
# Processing Record 30 of Set 14 | douglas
# Processing Record 31 of Set 14 | dabat
# Processing Record 32 of Set 14 | fairbanks
# Processing Record 33 of Set 14 | baghmara
# Processing Record 34 of Set 14 | chiang rai
# Processing Record 35 of Set 14 | cockburn harbour
# City not found. Skipping...
# Processing Record 36 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 37 of Set 14 | letterkenny
# Processing Record 38 of Set 14 | kabinda
# Processing Record 39 of Set 14 | nikki
# Processing Record 40 of Set 14 | springfield
# Processing Record 41 of Set 14 | sioux lookout
# Processing Record 42 of Set 14 | port blair
# Processing Record 43 of Set 14 | birjand
# Processing Record 44 of Set 14 | watertown
# Processing Record 45 of Set 14 | balabac
# Processing Record 46 of Set 14 | betamcherla
# Processing Record 47 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 48 of Set 14 | hobyo
# Processing Record 49 of Set 14 | makat
# Processing Record 50 of Set 14 | miraflores
# Processing Record 1 of Set 15 | el castillo
# Processing Record 2 of Set 15 | marmarion
# Processing Record 3 of Set 15 | yarada
# Processing Record 4 of Set 15 | megion
# Processing Record 5 of Set 15 | ellensburg
# Processing Record 6 of Set 15 | inirida
# Processing Record 7 of Set 15 | karratha
# Processing Record 8 of Set 15 | mata
# Processing Record 9 of Set 15 | red bluff
# Processing Record 10 of Set 15 | taiyuan
# Processing Record 11 of Set 15 | berea
# Processing Record 12 of Set 15 | hof
# Processing Record 13 of Set 15 | yerbogachen
# Processing Record 14 of Set 15 | emerald
# Processing Record 15 of Set 15 | okato
# Processing Record 16 of Set 15 | presidencia roque saenz pena
# Processing Record 17 of Set 15 | sangar
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Ponnani  10.7670   75.9252     79.92        84          56
# 1        Sladkovo  55.5284   70.3385     34.09        99          98
# 2  Saint-Philippe -21.3585   55.7679     72.99        86          55
# 3         Rikitea -23.1203 -134.9692     79.41        72           5
# 4         Karachi  24.9056   67.0822     82.22        44           0
# 5      Butaritari   3.0707  172.7902     81.25        79          99
# 6            Hilo  19.7297 -155.0900     80.33        73         100
# 7           Muros  42.7762   -9.0603     58.08        83         100
# 8          Albany  42.6001  -73.9662     47.64        91         100
# 9          Atuona  -9.8000 -139.0333     79.23        71          29
#
#    Wind Speed Country       Description                 Date
# 0        2.33      IN     broken clouds  2022-04-07 22:08:18
# 1       10.49      RU              snow  2022-04-07 22:13:15
# 2       14.18      RE        light rain  2022-04-07 22:09:17
# 3       15.66      PF         clear sky  2022-04-07 22:06:56
# 4        4.61      PK         clear sky  2022-04-07 22:08:24
# 5       13.80      KI        light rain  2022-04-07 22:06:57
# 6       13.80      US   overcast clouds  2022-04-07 22:10:54
# 7       20.49      ES   overcast clouds  2022-04-07 22:13:16
# 8        5.01      US     moderate rain  2022-04-07 22:10:41
# 9       14.79      PF  scattered clouds  2022-04-07 22:13:16

# %%
# Create the output file (CSV).
output_data_file = "../weather_data/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
