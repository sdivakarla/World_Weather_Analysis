# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
import json

# %%
import requests
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Import the API key.
from config import weather_api_key
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 781

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):


    # Group cities in sets of 50 for logging purposes.
        if (i % 50 == 0 and i >= 50):
            set_count += 1
            record_count = 1
            time.sleep(60)

    # Create endpoint URL with each city.
        city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
        print(f"Processing Record {record_count} of Set {set_count} | {city}")
        # Add 1 to the record count.
        record_count += 1
        
        # Run an API request for each of the cities.
        try:
        # Parse the JSON and retrieve data.
            city_weather = requests.get(city_url).json()
        # Parse out the needed data.
            city_lat = city_weather["coord"]["lat"]
            city_lng = city_weather["coord"]["lon"]
            city_max_temp = city_weather["main"]["temp_max"]
            city_humidity = city_weather["main"]["humidity"]
            city_clouds = city_weather["clouds"]["all"]
            city_wind = city_weather["wind"]["speed"]
            city_country = city_weather["sys"]["country"]
            weather_description = city_weather["weather"][0]['description']
        # Convert the date to ISO standard.
            city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
            city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": weather_description,
                          "Date": city_date})

        # If an error is experienced, skip the city.
        except:
            print("City not found. Skipping...")
            pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hilo
# Processing Record 2 of Set 1 | vaini
# Processing Record 3 of Set 1 | karratha
# Processing Record 4 of Set 1 | airai
# Processing Record 5 of Set 1 | yirol
# City not found. Skipping...
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | porto novo
# Processing Record 8 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 1 | yonibana
# Processing Record 11 of Set 1 | sun city west
# Processing Record 12 of Set 1 | san patricio
# Processing Record 13 of Set 1 | dikson
# Processing Record 14 of Set 1 | georgetown
# Processing Record 15 of Set 1 | zlatibor
# Processing Record 16 of Set 1 | mataura
# Processing Record 17 of Set 1 | baykit
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | port alfred
# Processing Record 20 of Set 1 | punta arenas
# Processing Record 21 of Set 1 | aleppo
# Processing Record 22 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 1 | rikitea
# Processing Record 24 of Set 1 | coahuayana
# Processing Record 25 of Set 1 | hobart
# Processing Record 26 of Set 1 | sikasso
# Processing Record 27 of Set 1 | baglung
# Processing Record 28 of Set 1 | barranco
# Processing Record 29 of Set 1 | kavieng
# Processing Record 30 of Set 1 | walvis bay
# Processing Record 31 of Set 1 | zhengjiatun
# Processing Record 32 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 33 of Set 1 | winnemucca
# Processing Record 34 of Set 1 | kapaa
# Processing Record 35 of Set 1 | jamestown
# Processing Record 36 of Set 1 | rongcheng
# Processing Record 37 of Set 1 | sibolga
# Processing Record 38 of Set 1 | hasaki
# Processing Record 39 of Set 1 | ushuaia
# Processing Record 40 of Set 1 | ribeira grande
# Processing Record 41 of Set 1 | guadalupe victoria
# Processing Record 42 of Set 1 | kahului
# Processing Record 43 of Set 1 | port alberni
# Processing Record 44 of Set 1 | kaitangata
# Processing Record 45 of Set 1 | dingle
# Processing Record 46 of Set 1 | pevek
# Processing Record 47 of Set 1 | san rafael del sur
# Processing Record 48 of Set 1 | saskylakh
# Processing Record 49 of Set 1 | bredasdorp
# Processing Record 50 of Set 1 | outjo
# Processing Record 1 of Set 2 | eyl
# Processing Record 2 of Set 2 | chancay
# Processing Record 3 of Set 2 | east london
# Processing Record 4 of Set 2 | avarua
# Processing Record 5 of Set 2 | seoul
# Processing Record 6 of Set 2 | khatanga
# Processing Record 7 of Set 2 | mount gambier
# Processing Record 8 of Set 2 | sonoita
# Processing Record 9 of Set 2 | los llanos de aridane
# Processing Record 10 of Set 2 | srivardhan
# Processing Record 11 of Set 2 | bluff
# Processing Record 12 of Set 2 | akim swedru
# Processing Record 13 of Set 2 | port elizabeth
# Processing Record 14 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 2 | san jeronimo
# Processing Record 16 of Set 2 | pori
# Processing Record 17 of Set 2 | gvarv
# Processing Record 18 of Set 2 | jimma
# Processing Record 19 of Set 2 | sao joao da barra
# Processing Record 20 of Set 2 | kirkenaer
# Processing Record 21 of Set 2 | fairbanks
# Processing Record 22 of Set 2 | dickinson
# Processing Record 23 of Set 2 | poum
# Processing Record 24 of Set 2 | thompson
# Processing Record 25 of Set 2 | lagoa
# Processing Record 26 of Set 2 | sarkand
# Processing Record 27 of Set 2 | namibe
# Processing Record 28 of Set 2 | iqaluit
# Processing Record 29 of Set 2 | cape town
# Processing Record 30 of Set 2 | tefe
# Processing Record 31 of Set 2 | portland
# Processing Record 32 of Set 2 | yibin
# Processing Record 33 of Set 2 | atasu
# Processing Record 34 of Set 2 | touros
# Processing Record 35 of Set 2 | isfana
# Processing Record 36 of Set 2 | dunedin
# Processing Record 37 of Set 2 | dhaulpur
# Processing Record 38 of Set 2 | atuona
# Processing Record 39 of Set 2 | mujiayingzi
# Processing Record 40 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 42 of Set 2 | lukovetskiy
# Processing Record 43 of Set 2 | batsfjord
# Processing Record 44 of Set 2 | nome
# Processing Record 45 of Set 2 | bethel
# Processing Record 46 of Set 2 | nanortalik
# Processing Record 47 of Set 2 | norman wells
# Processing Record 48 of Set 2 | chiang mai
# Processing Record 49 of Set 2 | talara
# Processing Record 50 of Set 2 | hermanus
# Processing Record 1 of Set 3 | byron bay
# Processing Record 2 of Set 3 | ayr
# Processing Record 3 of Set 3 | imisli
# City not found. Skipping...
# Processing Record 4 of Set 3 | te anau
# Processing Record 5 of Set 3 | ust-ishim
# Processing Record 6 of Set 3 | birao
# Processing Record 7 of Set 3 | castro
# Processing Record 8 of Set 3 | severo-kurilsk
# Processing Record 9 of Set 3 | sobolevo
# Processing Record 10 of Set 3 | vilyuysk
# Processing Record 11 of Set 3 | vao
# Processing Record 12 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 13 of Set 3 | tiarei
# Processing Record 14 of Set 3 | bandarbeyla
# Processing Record 15 of Set 3 | port moresby
# Processing Record 16 of Set 3 | manaus
# Processing Record 17 of Set 3 | elk plain
# Processing Record 18 of Set 3 | butaritari
# Processing Record 19 of Set 3 | yulara
# Processing Record 20 of Set 3 | new norfolk
# Processing Record 21 of Set 3 | aklavik
# Processing Record 22 of Set 3 | finschhafen
# Processing Record 23 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 24 of Set 3 | coihaique
# Processing Record 25 of Set 3 | port hardy
# Processing Record 26 of Set 3 | bilma
# Processing Record 27 of Set 3 | hamilton
# Processing Record 28 of Set 3 | qaanaaq
# Processing Record 29 of Set 3 | normandin
# Processing Record 30 of Set 3 | zhicheng
# Processing Record 31 of Set 3 | vardo
# Processing Record 32 of Set 3 | chapais
# Processing Record 33 of Set 3 | dillon
# Processing Record 34 of Set 3 | gangtok
# Processing Record 35 of Set 3 | barstow
# Processing Record 36 of Set 3 | oussouye
# Processing Record 37 of Set 3 | saiha
# Processing Record 38 of Set 3 | mbalmayo
# Processing Record 39 of Set 3 | sembe
# Processing Record 40 of Set 3 | ducheng
# Processing Record 41 of Set 3 | buique
# Processing Record 42 of Set 3 | saurimo
# Processing Record 43 of Set 3 | talcahuano
# Processing Record 44 of Set 3 | santa luzia
# Processing Record 45 of Set 3 | along
# Processing Record 46 of Set 3 | richards bay
# Processing Record 47 of Set 3 | carnarvon
# Processing Record 48 of Set 3 | bongandanga
# Processing Record 49 of Set 3 | yellowknife
# Processing Record 50 of Set 3 | krasnyy chikoy
# Processing Record 1 of Set 4 | nikolskoye
# Processing Record 2 of Set 4 | buala
# Processing Record 3 of Set 4 | longyearbyen
# Processing Record 4 of Set 4 | tadine
# Processing Record 5 of Set 4 | meulaboh
# Processing Record 6 of Set 4 | olyka
# Processing Record 7 of Set 4 | ponta do sol
# Processing Record 8 of Set 4 | morros
# Processing Record 9 of Set 4 | marfino
# Processing Record 10 of Set 4 | isangel
# Processing Record 11 of Set 4 | mawlaik
# Processing Record 12 of Set 4 | tabas
# Processing Record 13 of Set 4 | sulangan
# Processing Record 14 of Set 4 | talnakh
# Processing Record 15 of Set 4 | kirando
# Processing Record 16 of Set 4 | lalomanu
# City not found. Skipping...
# Processing Record 17 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 18 of Set 4 | olinda
# Processing Record 19 of Set 4 | westport
# Processing Record 20 of Set 4 | okhotsk
# Processing Record 21 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 22 of Set 4 | plouzane
# Processing Record 23 of Set 4 | pisco
# Processing Record 24 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 25 of Set 4 | kunashak
# Processing Record 26 of Set 4 | louis trichardt
# Processing Record 27 of Set 4 | high level
# Processing Record 28 of Set 4 | manicore
# Processing Record 29 of Set 4 | bafq
# Processing Record 30 of Set 4 | gboko
# Processing Record 31 of Set 4 | shimoda
# Processing Record 32 of Set 4 | miraflores
# Processing Record 33 of Set 4 | victoria
# Processing Record 34 of Set 4 | lake charles
# Processing Record 35 of Set 4 | mali
# Processing Record 36 of Set 4 | flinders
# Processing Record 37 of Set 4 | broken hill
# Processing Record 38 of Set 4 | santo estevao
# Processing Record 39 of Set 4 | ushtobe
# Processing Record 40 of Set 4 | pandan
# Processing Record 41 of Set 4 | luderitz
# Processing Record 42 of Set 4 | kuandian
# Processing Record 43 of Set 4 | nizwa
# Processing Record 44 of Set 4 | atherton
# Processing Record 45 of Set 4 | vila velha
# Processing Record 46 of Set 4 | calama
# Processing Record 47 of Set 4 | mar del plata
# Processing Record 48 of Set 4 | asosa
# Processing Record 49 of Set 4 | lavrentiya
# Processing Record 50 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 5 | shatsk
# Processing Record 2 of Set 5 | kirovsk
# Processing Record 3 of Set 5 | ugoofaaru
# Processing Record 4 of Set 5 | dubuque
# Processing Record 5 of Set 5 | kholtoson
# Processing Record 6 of Set 5 | souillac
# Processing Record 7 of Set 5 | alofi
# Processing Record 8 of Set 5 | saint george
# Processing Record 9 of Set 5 | tuatapere
# Processing Record 10 of Set 5 | husavik
# Processing Record 11 of Set 5 | harper
# Processing Record 12 of Set 5 | vytegra
# Processing Record 13 of Set 5 | constitucion
# Processing Record 14 of Set 5 | roald
# Processing Record 15 of Set 5 | olafsvik
# Processing Record 16 of Set 5 | mongoumba
# Processing Record 17 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 5 | urucui
# Processing Record 19 of Set 5 | vila franca do campo
# Processing Record 20 of Set 5 | port-de-bouc
# Processing Record 21 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 5 | kareli
# Processing Record 23 of Set 5 | saint-philippe
# Processing Record 24 of Set 5 | mildura
# Processing Record 25 of Set 5 | srednekolymsk
# Processing Record 26 of Set 5 | zyryanka
# Processing Record 27 of Set 5 | cayenne
# Processing Record 28 of Set 5 | nimbahera
# Processing Record 29 of Set 5 | tromso
# Processing Record 30 of Set 5 | chuy
# Processing Record 31 of Set 5 | buta
# Processing Record 32 of Set 5 | kodiak
# Processing Record 33 of Set 5 | puerto ayora
# Processing Record 34 of Set 5 | corinto
# Processing Record 35 of Set 5 | ahipara
# Processing Record 36 of Set 5 | seymchan
# Processing Record 37 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 5 | aripuana
# Processing Record 39 of Set 5 | port blair
# Processing Record 40 of Set 5 | itarema
# Processing Record 41 of Set 5 | petrovsk
# Processing Record 42 of Set 5 | robe
# Processing Record 43 of Set 5 | bathsheba
# Processing Record 44 of Set 5 | provideniya
# Processing Record 45 of Set 5 | kulhudhuffushi
# Processing Record 46 of Set 5 | usinsk
# Processing Record 47 of Set 5 | rawson
# Processing Record 48 of Set 5 | arraial do cabo
# Processing Record 49 of Set 5 | pangody
# Processing Record 50 of Set 5 | marawi
# Processing Record 1 of Set 6 | ostrovnoy
# Processing Record 2 of Set 6 | arcachon
# Processing Record 3 of Set 6 | lucea
# Processing Record 4 of Set 6 | ihosy
# Processing Record 5 of Set 6 | tasiilaq
# Processing Record 6 of Set 6 | arteaga
# Processing Record 7 of Set 6 | padang
# Processing Record 8 of Set 6 | barrow
# Processing Record 9 of Set 6 | pangnirtung
# Processing Record 10 of Set 6 | leo
# Processing Record 11 of Set 6 | umm lajj
# Processing Record 12 of Set 6 | dzilam gonzalez
# Processing Record 13 of Set 6 | morki
# Processing Record 14 of Set 6 | dafeng
# Processing Record 15 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 16 of Set 6 | velyka lepetykha
# Processing Record 17 of Set 6 | lerwick
# Processing Record 18 of Set 6 | yasnyy
# Processing Record 19 of Set 6 | salinas
# Processing Record 20 of Set 6 | sur
# Processing Record 21 of Set 6 | san quintin
# Processing Record 22 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 23 of Set 6 | kruisfontein
# Processing Record 24 of Set 6 | bababe
# City not found. Skipping...
# Processing Record 25 of Set 6 | alice springs
# Processing Record 26 of Set 6 | buritizeiro
# Processing Record 27 of Set 6 | sebinkarahisar
# Processing Record 28 of Set 6 | kungurtug
# Processing Record 29 of Set 6 | aswan
# Processing Record 30 of Set 6 | puerto quijarro
# Processing Record 31 of Set 6 | pilar
# Processing Record 32 of Set 6 | la ronge
# Processing Record 33 of Set 6 | luanda
# Processing Record 34 of Set 6 | mahebourg
# Processing Record 35 of Set 6 | risod
# Processing Record 36 of Set 6 | the valley
# Processing Record 37 of Set 6 | back mountain
# Processing Record 38 of Set 6 | carahue
# Processing Record 39 of Set 6 | lismore
# Processing Record 40 of Set 6 | ocho rios
# Processing Record 41 of Set 6 | redding
# Processing Record 42 of Set 6 | tuktoyaktuk
# Processing Record 43 of Set 6 | pacific grove
# Processing Record 44 of Set 6 | palafrugell
# Processing Record 45 of Set 6 | jiuquan
# Processing Record 46 of Set 6 | ahuimanu
# Processing Record 47 of Set 6 | severnyy
# Processing Record 48 of Set 6 | bukama
# Processing Record 49 of Set 6 | sioux lookout
# Processing Record 50 of Set 6 | muncar
# Processing Record 1 of Set 7 | sorong
# Processing Record 2 of Set 7 | abnub
# Processing Record 3 of Set 7 | gushikawa
# Processing Record 4 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 7 | pau dos ferros
# Processing Record 6 of Set 7 | cairns
# Processing Record 7 of Set 7 | kununurra
# Processing Record 8 of Set 7 | atar
# Processing Record 9 of Set 7 | grand gaube
# Processing Record 10 of Set 7 | tayu
# Processing Record 11 of Set 7 | hay river
# Processing Record 12 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 13 of Set 7 | mao
# Processing Record 14 of Set 7 | klaksvik
# Processing Record 15 of Set 7 | campo grande
# Processing Record 16 of Set 7 | gidole
# Processing Record 17 of Set 7 | bengkulu
# Processing Record 18 of Set 7 | turinsk
# Processing Record 19 of Set 7 | torbay
# Processing Record 20 of Set 7 | salyan
# Processing Record 21 of Set 7 | galesong
# Processing Record 22 of Set 7 | ossora
# Processing Record 23 of Set 7 | chokurdakh
# Processing Record 24 of Set 7 | san andres
# Processing Record 25 of Set 7 | bambous virieux
# Processing Record 26 of Set 7 | san cristobal
# Processing Record 27 of Set 7 | liberal
# Processing Record 28 of Set 7 | la tuque
# Processing Record 29 of Set 7 | cidreira
# Processing Record 30 of Set 7 | cap malheureux
# Processing Record 31 of Set 7 | mana
# Processing Record 32 of Set 7 | sili
# Processing Record 33 of Set 7 | axim
# Processing Record 34 of Set 7 | tecozautla
# Processing Record 35 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 36 of Set 7 | katsuura
# Processing Record 37 of Set 7 | eskasem
# City not found. Skipping...
# Processing Record 38 of Set 7 | jumla
# Processing Record 39 of Set 7 | sakakah
# Processing Record 40 of Set 7 | amursk
# Processing Record 41 of Set 7 | saint anthony
# Processing Record 42 of Set 7 | yunjinghong
# City not found. Skipping...
# Processing Record 43 of Set 7 | ilheus
# Processing Record 44 of Set 7 | eureka
# Processing Record 45 of Set 7 | iralaya
# Processing Record 46 of Set 7 | codrington
# Processing Record 47 of Set 7 | kousseri
# Processing Record 48 of Set 7 | ewa beach
# Processing Record 49 of Set 7 | coromandel
# Processing Record 50 of Set 7 | baruun-urt
# Processing Record 1 of Set 8 | lazaro cardenas
# Processing Record 2 of Set 8 | muli
# Processing Record 3 of Set 8 | dunmore town
# Processing Record 4 of Set 8 | banjar
# Processing Record 5 of Set 8 | stutterheim
# Processing Record 6 of Set 8 | talaya
# Processing Record 7 of Set 8 | shushtar
# Processing Record 8 of Set 8 | aitape
# Processing Record 9 of Set 8 | rock springs
# Processing Record 10 of Set 8 | tongliao
# Processing Record 11 of Set 8 | mount isa
# Processing Record 12 of Set 8 | tarakan
# Processing Record 13 of Set 8 | maniitsoq
# Processing Record 14 of Set 8 | nampula
# Processing Record 15 of Set 8 | romitan
# Processing Record 16 of Set 8 | teguldet
# Processing Record 17 of Set 8 | abu zabad
# Processing Record 18 of Set 8 | grindavik
# Processing Record 19 of Set 8 | duarte
# Processing Record 20 of Set 8 | illora
# Processing Record 21 of Set 8 | charagua
# Processing Record 22 of Set 8 | inuvik
# Processing Record 23 of Set 8 | matara
# Processing Record 24 of Set 8 | sawtell
# Processing Record 25 of Set 8 | zhigansk
# Processing Record 26 of Set 8 | almansa
# Processing Record 27 of Set 8 | lorengau
# Processing Record 28 of Set 8 | lagos
# Processing Record 29 of Set 8 | wanning
# Processing Record 30 of Set 8 | qui nhon
# Processing Record 31 of Set 8 | acajutla
# Processing Record 32 of Set 8 | sitka
# Processing Record 33 of Set 8 | sumbe
# Processing Record 34 of Set 8 | bowen
# Processing Record 35 of Set 8 | cukai
# Processing Record 36 of Set 8 | daru
# Processing Record 37 of Set 8 | saint-pierre
# Processing Record 38 of Set 8 | laguna
# Processing Record 39 of Set 8 | ancud
# Processing Record 40 of Set 8 | tura
# Processing Record 41 of Set 8 | impfondo
# Processing Record 42 of Set 8 | tecolutla
# Processing Record 43 of Set 8 | mareeba
# Processing Record 44 of Set 8 | sistranda
# Processing Record 45 of Set 8 | sambava
# Processing Record 46 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 47 of Set 8 | brae
# Processing Record 48 of Set 8 | colares
# Processing Record 49 of Set 8 | jatai
# Processing Record 50 of Set 8 | upernavik
# Processing Record 1 of Set 9 | tornio
# Processing Record 2 of Set 9 | kuusamo
# Processing Record 3 of Set 9 | brownsville
# Processing Record 4 of Set 9 | glubokoe
# City not found. Skipping...
# Processing Record 5 of Set 9 | gorontalo
# Processing Record 6 of Set 9 | marang
# Processing Record 7 of Set 9 | alta floresta
# Processing Record 8 of Set 9 | boa vista
# Processing Record 9 of Set 9 | taoudenni
# Processing Record 10 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 9 | jiddah
# City not found. Skipping...
# Processing Record 12 of Set 9 | nuevitas
# Processing Record 13 of Set 9 | bud
# Processing Record 14 of Set 9 | broome
# Processing Record 15 of Set 9 | yiyang
# Processing Record 16 of Set 9 | clyde river
# Processing Record 17 of Set 9 | uyuni
# Processing Record 18 of Set 9 | khani
# Processing Record 19 of Set 9 | cheuskiny
# City not found. Skipping...
# Processing Record 20 of Set 9 | portobelo
# Processing Record 21 of Set 9 | barcs
# Processing Record 22 of Set 9 | faanui
# Processing Record 23 of Set 9 | ilulissat
# Processing Record 24 of Set 9 | bull savanna
# Processing Record 25 of Set 9 | van buren
# Processing Record 26 of Set 9 | gat
# Processing Record 27 of Set 9 | haines junction
# Processing Record 28 of Set 9 | karagay
# Processing Record 29 of Set 9 | mbekenyera
# Processing Record 30 of Set 9 | kisangani
# Processing Record 31 of Set 9 | erzin
# Processing Record 32 of Set 9 | villanueva
# Processing Record 33 of Set 9 | balsas
# Processing Record 34 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 35 of Set 9 | dezhou
# Processing Record 36 of Set 9 | skibbereen
# Processing Record 37 of Set 9 | kasongo-lunda
# Processing Record 38 of Set 9 | petropavl
# Processing Record 39 of Set 9 | bonthe
# Processing Record 40 of Set 9 | mehamn
# Processing Record 41 of Set 9 | santa cruz
# Processing Record 42 of Set 9 | imeni poliny osipenko
# Processing Record 43 of Set 9 | verkhoyansk
# Processing Record 44 of Set 9 | tiksi
# Processing Record 45 of Set 9 | dakoro
# Processing Record 46 of Set 9 | urumqi
# Processing Record 47 of Set 9 | ostersund
# Processing Record 48 of Set 9 | esperance
# Processing Record 49 of Set 9 | mumbwa
# Processing Record 50 of Set 9 | nantucket
# Processing Record 1 of Set 10 | itaiba
# Processing Record 2 of Set 10 | sauce
# Processing Record 3 of Set 10 | iberia
# Processing Record 4 of Set 10 | bundaberg
# Processing Record 5 of Set 10 | svetlogorsk
# Processing Record 6 of Set 10 | jalali
# Processing Record 7 of Set 10 | lebu
# Processing Record 8 of Set 10 | locri
# Processing Record 9 of Set 10 | yueyang
# Processing Record 10 of Set 10 | evensk
# Processing Record 11 of Set 10 | shingu
# Processing Record 12 of Set 10 | arkhangelos
# City not found. Skipping...
# Processing Record 13 of Set 10 | yelizovo
# Processing Record 14 of Set 10 | bay roberts
# Processing Record 15 of Set 10 | mayo
# Processing Record 16 of Set 10 | guerrero negro
# Processing Record 17 of Set 10 | bilibino
# Processing Record 18 of Set 10 | ollioules
# Processing Record 19 of Set 10 | rio grande
# Processing Record 20 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 21 of Set 10 | sterling
# Processing Record 22 of Set 10 | fairlie
# Processing Record 23 of Set 10 | lasa
# Processing Record 24 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 25 of Set 10 | saint-francois
# Processing Record 26 of Set 10 | benjamin constant
# Processing Record 27 of Set 10 | port hedland
# Processing Record 28 of Set 10 | kapoeta
# Processing Record 29 of Set 10 | acapulco
# Processing Record 30 of Set 10 | rio gallegos
# Processing Record 31 of Set 10 | sao filipe
# Processing Record 32 of Set 10 | dzhusaly
# City not found. Skipping...
# Processing Record 33 of Set 10 | balakirevo
# Processing Record 34 of Set 10 | havre-saint-pierre
# Processing Record 35 of Set 10 | verkhnevilyuysk
# Processing Record 36 of Set 10 | altay
# Processing Record 37 of Set 10 | yenagoa
# Processing Record 38 of Set 10 | hithadhoo
# Processing Record 39 of Set 10 | erkrath
# Processing Record 40 of Set 10 | praia da vitoria
# Processing Record 41 of Set 10 | prince rupert
# Processing Record 42 of Set 10 | vilcun
# Processing Record 43 of Set 10 | labuhan
# Processing Record 44 of Set 10 | lodja
# Processing Record 45 of Set 10 | naliya
# Processing Record 46 of Set 10 | santa elena
# Processing Record 47 of Set 10 | dhidhdhoo
# Processing Record 48 of Set 10 | coquimbo
# Processing Record 49 of Set 10 | nyurba
# Processing Record 50 of Set 10 | lafia
# Processing Record 1 of Set 11 | fuyang
# Processing Record 2 of Set 11 | belmonte
# Processing Record 3 of Set 11 | honiara
# Processing Record 4 of Set 11 | saint-joseph
# Processing Record 5 of Set 11 | umm bab
# Processing Record 6 of Set 11 | booue
# Processing Record 7 of Set 11 | porteirinha
# Processing Record 8 of Set 11 | kabompo
# Processing Record 9 of Set 11 | sokoni
# Processing Record 10 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 11 of Set 11 | felanitx
# Processing Record 12 of Set 11 | parit raja
# Processing Record 13 of Set 11 | abha
# Processing Record 14 of Set 11 | khorinsk
# Processing Record 15 of Set 11 | kerrville
# Processing Record 16 of Set 11 | saldanha
# Processing Record 17 of Set 11 | dongsheng
# Processing Record 18 of Set 11 | nawa
# Processing Record 19 of Set 11 | narsaq
# Processing Record 20 of Set 11 | nabire
# Processing Record 21 of Set 11 | tezu
# Processing Record 22 of Set 11 | kholodnyy
# Processing Record 23 of Set 11 | altagracia de orituco
# Processing Record 24 of Set 11 | bonavista
# Processing Record 25 of Set 11 | minggang
# Processing Record 26 of Set 11 | cockburn town
# Processing Record 27 of Set 11 | asfi
# Processing Record 28 of Set 11 | ust-omchug
# Processing Record 29 of Set 11 | pangai
# Processing Record 30 of Set 11 | shalya
# Processing Record 31 of Set 11 | saint-augustin
# Processing Record 32 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 33 of Set 11 | niort
# Processing Record 34 of Set 11 | bathurst
# Processing Record 35 of Set 11 | betong
# Processing Record 36 of Set 11 | iguape
# Processing Record 37 of Set 11 | minab
# Processing Record 38 of Set 11 | ndele
# Processing Record 39 of Set 11 | bykovo
# Processing Record 40 of Set 11 | longlac
# City not found. Skipping...
# Processing Record 41 of Set 11 | cabo san lucas
# Processing Record 42 of Set 11 | hearst
# Processing Record 43 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 11 | port-cartier
# Processing Record 45 of Set 11 | yaan
# Processing Record 46 of Set 11 | union city
# Processing Record 47 of Set 11 | mont-dore
# Processing Record 48 of Set 11 | luwuk
# Processing Record 49 of Set 11 | outlook
# Processing Record 50 of Set 11 | chumikan
# Processing Record 1 of Set 12 | midland
# Processing Record 2 of Set 12 | anadyr
# Processing Record 3 of Set 12 | namatanai
# Processing Record 4 of Set 12 | baghdad
# Processing Record 5 of Set 12 | viedma
# Processing Record 6 of Set 12 | kolyvan
# Processing Record 7 of Set 12 | port-gentil
# Processing Record 8 of Set 12 | kondinskoye
# Processing Record 9 of Set 12 | la palma
# Processing Record 10 of Set 12 | valera
# Processing Record 11 of Set 12 | north bend
# Processing Record 12 of Set 12 | avera
# Processing Record 13 of Set 12 | turan
# Processing Record 14 of Set 12 | krasnoselkup
# Processing Record 15 of Set 12 | oyama
# Processing Record 16 of Set 12 | port augusta
# Processing Record 17 of Set 12 | kerman
# Processing Record 18 of Set 12 | dobryanka
# Processing Record 19 of Set 12 | igarka
# Processing Record 20 of Set 12 | geraldton
# Processing Record 21 of Set 12 | odweyne
# Processing Record 22 of Set 12 | ilo
# Processing Record 23 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 24 of Set 12 | szilvasvarad
# Processing Record 25 of Set 12 | hokitika
# Processing Record 26 of Set 12 | ixtapa
# Processing Record 27 of Set 12 | manzanillo
# Processing Record 28 of Set 12 | valdagno
# Processing Record 29 of Set 12 | goundi
# Processing Record 30 of Set 12 | guhagar
# Processing Record 31 of Set 12 | dekernes
# Processing Record 32 of Set 12 | kirensk
# Processing Record 33 of Set 12 | qeshm
# Processing Record 34 of Set 12 | oksfjord
# Processing Record 35 of Set 12 | auki
# Processing Record 36 of Set 12 | pacov
# Processing Record 37 of Set 12 | dalbandin
# Processing Record 38 of Set 12 | sabha
# Processing Record 39 of Set 12 | santa maria do suacui
# Processing Record 40 of Set 12 | yarada
# Processing Record 41 of Set 12 | nadym
# Processing Record 42 of Set 12 | nueva loja
# Processing Record 43 of Set 12 | maharajganj
# Processing Record 44 of Set 12 | esso
# Processing Record 45 of Set 12 | hami
# Processing Record 46 of Set 12 | ust-kuyga
# Processing Record 47 of Set 12 | leningradskiy
# Processing Record 48 of Set 12 | kadhan
# Processing Record 49 of Set 12 | moose factory
# Processing Record 50 of Set 12 | kefamenanu
# Processing Record 1 of Set 13 | abay
# Processing Record 2 of Set 13 | maceio
# Processing Record 3 of Set 13 | xining
# Processing Record 4 of Set 13 | samarai
# Processing Record 5 of Set 13 | chake chake
# Processing Record 6 of Set 13 | kaeo
# Processing Record 7 of Set 13 | hofn
# Processing Record 8 of Set 13 | willowmore
# Processing Record 9 of Set 13 | fortuna
# Processing Record 10 of Set 13 | leticia
# Processing Record 11 of Set 13 | kaupanger
# Processing Record 12 of Set 13 | biak
# Processing Record 13 of Set 13 | jalingo
# Processing Record 14 of Set 13 | chicama
# Processing Record 15 of Set 13 | kailua
# Processing Record 16 of Set 13 | svetlyy
# Processing Record 17 of Set 13 | sola
# Processing Record 18 of Set 13 | vinstra
# Processing Record 19 of Set 13 | zdvinsk
# Processing Record 20 of Set 13 | caravelas
# Processing Record 21 of Set 13 | torit
# Processing Record 22 of Set 13 | ueki
# Processing Record 23 of Set 13 | dutlwe
# Processing Record 24 of Set 13 | bow island
# Processing Record 25 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 26 of Set 13 | ulladulla
# Processing Record 27 of Set 13 | kemijarvi
# Processing Record 28 of Set 13 | tocache
# Processing Record 29 of Set 13 | luganville
# Processing Record 30 of Set 13 | prnjavor
# Processing Record 31 of Set 13 | pangkalanbuun
# Processing Record 32 of Set 13 | santa rosa
# Processing Record 33 of Set 13 | biu
# Processing Record 34 of Set 13 | qaqortoq
# Processing Record 35 of Set 13 | asau
# Processing Record 36 of Set 13 | bambui
# Processing Record 37 of Set 13 | deputatskiy
# Processing Record 38 of Set 13 | sidi ali
# Processing Record 39 of Set 13 | san carlos de bariloche
# Processing Record 40 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 41 of Set 13 | chimbote
# Processing Record 42 of Set 13 | necochea
# Processing Record 43 of Set 13 | hallingby
# City not found. Skipping...
# Processing Record 44 of Set 13 | aguimes
# Processing Record 45 of Set 13 | vila
# Processing Record 46 of Set 13 | trincomalee
# Processing Record 47 of Set 13 | gemena
# Processing Record 48 of Set 13 | kawardha
# Processing Record 49 of Set 13 | clifton
# Processing Record 50 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 1 of Set 14 | gambela
# Processing Record 2 of Set 14 | margate
# Processing Record 3 of Set 14 | osterburg
# Processing Record 4 of Set 14 | siocon
# Processing Record 5 of Set 14 | sheksna
# Processing Record 6 of Set 14 | palmer
# Processing Record 7 of Set 14 | wilmington
# Processing Record 8 of Set 14 | pitimbu
# Processing Record 9 of Set 14 | mullaitivu
# City not found. Skipping...
# Processing Record 10 of Set 14 | nurota
# Processing Record 11 of Set 14 | kokoda
# Processing Record 12 of Set 14 | manggar
# Processing Record 13 of Set 14 | tagusao
# Processing Record 14 of Set 14 | kilindoni
# Processing Record 15 of Set 14 | ornskoldsvik
# Processing Record 16 of Set 14 | taltal
# Processing Record 17 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 18 of Set 14 | banmankhi
# Processing Record 19 of Set 14 | kavaratti
# Processing Record 20 of Set 14 | kokopo
# Processing Record 21 of Set 14 | bara
# Processing Record 22 of Set 14 | gori
# Processing Record 23 of Set 14 | sawakin
# Processing Record 24 of Set 14 | lompoc
# Processing Record 25 of Set 14 | manta
# Processing Record 26 of Set 14 | astoria
# Processing Record 27 of Set 14 | addi ugri
# City not found. Skipping...
# Processing Record 28 of Set 14 | ziarat
# Processing Record 29 of Set 14 | cervo
# Processing Record 30 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 31 of Set 14 | karamea
# City not found. Skipping...
# Processing Record 32 of Set 14 | villiers
# Processing Record 33 of Set 14 | matamoros
# Processing Record 34 of Set 14 | umm durman
# City not found. Skipping...
# Processing Record 35 of Set 14 | grand-santi
# Processing Record 36 of Set 14 | mosjoen
# Processing Record 37 of Set 14 | riberalta
# Processing Record 38 of Set 14 | port lincoln
# Processing Record 39 of Set 14 | cherskiy
# Processing Record 40 of Set 14 | kabare
# Processing Record 41 of Set 14 | darhan
# Processing Record 42 of Set 14 | mbandaka
# Processing Record 43 of Set 14 | khandyga
# Processing Record 44 of Set 14 | yar-sale
# Processing Record 45 of Set 14 | bakel
# Processing Record 46 of Set 14 | nizhniy kuranakh
# Processing Record 47 of Set 14 | kargasok
# Processing Record 48 of Set 14 | yumen
# Processing Record 49 of Set 14 | kusti
# Processing Record 50 of Set 14 | taupo
# Processing Record 1 of Set 15 | maltahohe
# Processing Record 2 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 3 of Set 15 | half moon bay
# Processing Record 4 of Set 15 | lata
# Processing Record 5 of Set 15 | kochki
# Processing Record 6 of Set 15 | burnie
# Processing Record 7 of Set 15 | shenjiamen
# Processing Record 8 of Set 15 | tidore
# City not found. Skipping...
# Processing Record 9 of Set 15 | nuuk
# Processing Record 10 of Set 15 | pochutla
# Processing Record 11 of Set 15 | kyabe
# Processing Record 12 of Set 15 | conde
# Processing Record 13 of Set 15 | strunino
# Processing Record 14 of Set 15 | salalah
# Processing Record 15 of Set 15 | sahrak
# City not found. Skipping...
# Processing Record 16 of Set 15 | benghazi
# Processing Record 17 of Set 15 | khvastovichi
# Processing Record 18 of Set 15 | teknaf
# Processing Record 19 of Set 15 | meadow lake
# Processing Record 20 of Set 15 | koboldo
# City not found. Skipping...
# Processing Record 21 of Set 15 | valente
# Processing Record 22 of Set 15 | jiblah
# Processing Record 23 of Set 15 | novyy urgal
# Processing Record 24 of Set 15 | panjab
# Processing Record 25 of Set 15 | la asuncion
# Processing Record 26 of Set 15 | udachnyy
# Processing Record 27 of Set 15 | sault sainte marie
# Processing Record 28 of Set 15 | labutta
# City not found. Skipping...
# Processing Record 29 of Set 15 | ambikapur
# Processing Record 30 of Set 15 | la baule-escoublac
# Processing Record 31 of Set 15 | hihifo
# City not found. Skipping...
# Processing Record 32 of Set 15 | songkhla
# Processing Record 33 of Set 15 | nsanje
# Processing Record 34 of Set 15 | okha
# Processing Record 35 of Set 15 | hit
# Processing Record 36 of Set 15 | spirit river
# Processing Record 37 of Set 15 | opuwo
# Processing Record 38 of Set 15 | traralgon
# Processing Record 39 of Set 15 | akdepe
# Processing Record 40 of Set 15 | kunya
# Processing Record 41 of Set 15 | frisco
# Processing Record 42 of Set 15 | baoding
# Processing Record 43 of Set 15 | uchaly
# Processing Record 44 of Set 15 | antofagasta
# Processing Record 45 of Set 15 | merritt island
# Processing Record 46 of Set 15 | kupang
# Processing Record 47 of Set 15 | kimbe
# Processing Record 48 of Set 15 | valparaiso
# Processing Record 49 of Set 15 | stokke
# Processing Record 50 of Set 15 | ayagoz
# Processing Record 1 of Set 16 | san pedro
# Processing Record 2 of Set 16 | porangatu
# Processing Record 3 of Set 16 | camacha
# Processing Record 4 of Set 16 | aksarka
# Processing Record 5 of Set 16 | laela
# Processing Record 6 of Set 16 | minna
# Processing Record 7 of Set 16 | komsomolskiy
# Processing Record 8 of Set 16 | neuquen
# Processing Record 9 of Set 16 | gua musang
# Processing Record 10 of Set 16 | churachandpur
# Processing Record 11 of Set 16 | rawannawi
# City not found. Skipping...
# Processing Record 12 of Set 16 | malanje
# Processing Record 13 of Set 16 | naze
# Processing Record 14 of Set 16 | bojnurd
# Processing Record 15 of Set 16 | bereda
# Processing Record 16 of Set 16 | sao jose da coroa grande
# Processing Record 17 of Set 16 | san lorenzo
# Processing Record 18 of Set 16 | zinder
# Processing Record 19 of Set 16 | tilichiki
# Processing Record 20 of Set 16 | praia
# Processing Record 21 of Set 16 | roma
# Processing Record 22 of Set 16 | chicxulub
# Processing Record 23 of Set 16 | ondorhaan
# City not found. Skipping...
# Processing Record 24 of Set 16 | noumea
# Processing Record 25 of Set 16 | langham
# Processing Record 26 of Set 16 | el tigre
# Processing Record 27 of Set 16 | ixcaquixtla
# City not found. Skipping...
# Processing Record 28 of Set 16 | pundaguitan
# Processing Record 29 of Set 16 | fengcheng
# Processing Record 30 of Set 16 | scalloway
# City not found. Skipping...
# Processing Record 31 of Set 16 | gawler
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Hilo  19.7297 -155.0900     71.33        88         100
# 1          Vaini -21.2000 -175.2000     77.16        94          75
# 2       Karratha -20.7377  116.8463     84.61        28           2
# 3          Airai  -8.9266  125.4092     59.95        64         100
# 4      Busselton -33.6500  115.3333     58.78        79           7
# 5     Porto Novo   6.4965    2.6036     89.42        55          94
# 6       Yonibana   8.4447  -12.2450    104.61        29          94
# 7  Sun City West  33.6620 -112.3413     72.23        45           0
# 8   San Patricio  28.0170  -97.5169     76.87        74         100
# 9         Dikson  73.5069   80.5464      0.66        92          90
#
#    Wind Speed Country              Description                 Date
# 0        3.44      US          overcast clouds  2022-04-11 14:52:16
# 1        8.05      TO  light intensity drizzle  2022-04-11 14:52:35
# 2       12.66      AU                clear sky  2022-04-11 14:52:35
# 3        1.86      TL          overcast clouds  2022-04-11 14:51:36
# 4       10.76      AU                clear sky  2022-04-11 14:52:36
# 5       10.83      BJ          overcast clouds  2022-04-11 14:52:36
# 6        1.23      SL          overcast clouds  2022-04-11 14:52:37
# 7        4.00      US                clear sky  2022-04-11 14:51:00
# 8       18.23      US          overcast clouds  2022-04-11 14:52:37
# 9        8.57      RU          overcast clouds  2022-04-11 14:47:59

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
